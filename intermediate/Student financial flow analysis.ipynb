# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    rollno     id  tAmount  paid  balance
# 0       1  100.0   5000.0  2000     3000
# 1       2  101.0   6000.0  4000     2000
# 2       3  102.0   5000.0  5000        0
# 3       4    NaN   7000.0  5000     2000
# 4       5  104.0   4000.0     0     4000
# 5       6  105.0   7000.0  2000     5000
# 6       7  106.0   5000.0  1000     4000
# 7       8  107.0      NaN  5000     3000
# 8       9  108.0   6000.0  4500     1500
# 9      10  109.0   8000.0  7000     1000

# %%
df.isnull()
# Out:
#    rollno     id  tAmount   paid  balance
# 0   False  False    False  False    False
# 1   False  False    False  False    False
# 2   False  False    False  False    False
# 3   False   True    False  False    False
# 4   False  False    False  False    False
# 5   False  False    False  False    False
# 6   False  False    False  False    False
# 7   False  False     True  False    False
# 8   False  False    False  False    False
# 9   False  False    False  False    False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rollno   10 non-null     int64
#  1   id       9 non-null      float64
#  2   tAmount  9 non-null      float64
#  3   paid     10 non-null     int64
#  4   balance  10 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 532.0 bytes

# %%
df.isnull().sum()
# Out:
# rollno     0
# id         1
# tAmount    1
# paid       0
# balance    0
# dtype: int64

# %%
df.head(8)
# Out:
#    rollno     id  tAmount  paid  balance
# 0       1  100.0   5000.0  2000     3000
# 1       2  101.0   6000.0  4000     2000
# 2       3  102.0   5000.0  5000        0
# 3       4    NaN   7000.0  5000     2000
# 4       5  104.0   4000.0     0     4000
# 5       6  105.0   7000.0  2000     5000
# 6       7  106.0   5000.0  1000     4000
# 7       8  107.0      NaN  5000     3000

# %%
df.id.median()
# Out:
# 105.0

# %%
df.id=df.id.fillna(df.id.median())

# %%
df
# Out:
#    rollno     id  tAmount  paid  balance
# 0       1  100.0   5000.0  2000     3000
# 1       2  101.0   6000.0  4000     2000
# 2       3  102.0   5000.0  5000        0
# 3       4  105.0   7000.0  5000     2000
# 4       5  104.0   4000.0     0     4000
# 5       6  105.0   7000.0  2000     5000
# 6       7  106.0   5000.0  1000     4000
# 7       8  107.0      NaN  5000     3000
# 8       9  108.0   6000.0  4500     1500
# 9      10  109.0   8000.0  7000     1000

# %%
df.tAmount.median()
# Out:
# 6000.0

# %%
df.tAmount=df.tAmount.fillna(df.tAmount.median())
df
# Out:
#    rollno     id  tAmount  paid  balance
# 0       1  100.0   5000.0  2000     3000
# 1       2  101.0   6000.0  4000     2000
# 2       3  102.0   5000.0  5000        0
# 3       4  105.0   7000.0  5000     2000
# 4       5  104.0   4000.0     0     4000
# 5       6  105.0   7000.0  2000     5000
# 6       7  106.0   5000.0  1000     4000
# 7       8  107.0   6000.0  5000     3000
# 8       9  108.0   6000.0  4500     1500
# 9      10  109.0   8000.0  7000     1000

# %%
reg=linear_model.LinearRegression()
reg.fit(df.drop('balance',axis='columns'),df.balance)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([ 89.11935618, -19.7793202 ,   0.78925887,  -0.88177374])

# %%
reg.intercept_
# Out:
# 2604.4078310199966

# %%
reg.predict([[11,21,6000,4000]])
# Out:
# D:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4377.81326385])

# %%
 89.11935618*11+19.7793202*21+0.78925887*6000+-0.88177374*4000+4377.81326385
# Out:
# 6981.950166029999

# %%
import matplotlib.pyplot as plt

plt.scatter(df['rollno'],df['balance'],color='red',label='dot')
plt.plot(df['rollno'],df['balance'],label='line')
plt.title('graph')
plt.legend()
plt.xlabel('Rollno')
plt.ylabel('Balance')
plt.show()

# %%
plt.bar(df['rollno'],df['balance'],color=['red','blue','pink','green'])
plt.show()

# %%
plt.hist(df['tAmount'])
plt.show()
